# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#loading the dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#data cleanup

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#               job_title_short  \
# 309395          Data Engineer
# 418639   Senior Data Engineer
# 624247  Senior Data Scientist
# 425282      Software Engineer
# 701066           Data Analyst
# 22335   Senior Data Scientist
# 29648            Data Analyst
# 46598        Business Analyst
# 318474       Business Analyst
# 209274         Data Scientist
#
#                                                 job_title  \
# 309395                    Data Engineer, Data & Reporting
# 418639                               Senior Data Engineer
# 624247             Data Scientist / Senior Data Scientist
# 425282                           Middle Software Engineer
# 701066  Data Analyst - Part Time (Greater NYC Area, NY...
# 22335                               Senior Data Scientist
# 29648                                    Data Analyst H/F
# 46598          Commercial & Business Intelligence Analyst
# 318474                    Operational Performance Analyst
# 209274                             Data Scientist Faculty
#
#                         job_location                          job_via  \
# 309395           Zürich, Switzerland              via UBS - Talentify
# 418639                    London, UK                        via BeBee
# 624247             İstanbul, Türkiye                     via LinkedIn
# 425282      Bogotá, Bogota, Colombia               via BeBee Colombia
# 701066                      Anywhere                 via Built In NYC
# 22335                       Anywhere                     via LinkedIn
# 29648   Boulogne-Billancourt, France                       via Indeed
# 46598            Geneva, Switzerland  via Central Illinois Proud Jobs
# 318474             Stockholm, Sweden                     via LinkedIn
# 209274                Washington, DC                 via ZipRecruiter
#
#        job_schedule_type  job_work_from_home          search_location  \
# 309395         Full-time               False              Switzerland
# 418639         Full-time               False           United Kingdom
# 624247         Full-time               False                   Turkey
# 425282         Full-time               False                 Colombia
# 701066         Part-time                True  New York, United States
# 22335          Full-time                True                    Spain
# 29648          Full-time               False                   France
# 46598          Full-time               False              Switzerland
# 318474         Full-time               False                   Sweden
# 209274         Full-time               False                  Georgia
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 309395 2023-03-17 17:36:32                  False                 False
# 418639 2023-08-17 16:18:24                   True                 False
# 624247 2023-04-03 12:37:12                  False                 False
# 425282 2023-03-02 16:32:19                   True                 False
# 701066 2023-09-22 02:59:54                   True                 False
# 22335  2023-08-08 13:21:24                  False                 False
# 29648  2023-11-14 13:37:24                  False                 False
# 46598  2023-03-25 06:34:46                  False                 False
# 318474 2023-04-06 17:12:15                  False                 False
# 209274 2023-10-05 22:42:31                  False                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 309395     Switzerland         NaN              NaN              NaN
# 418639  United Kingdom         NaN              NaN              NaN
# 624247          Turkey         NaN              NaN              NaN
# 425282        Colombia         NaN              NaN              NaN
# 701066   United States        year          83200.0              NaN
# 22335            Spain         NaN              NaN              NaN
# 29648           France         NaN              NaN              NaN
# 46598      Switzerland         NaN              NaN              NaN
# 318474          Sweden         NaN              NaN              NaN
# 209274   United States         NaN              NaN              NaN
#
#                                   company_name  \
# 309395                                     UBS
# 418639                                 Zalando
# 624247                                Linktera
# 425282                             AgileEngine
# 701066  Memorial Sloan Kettering Cancer Center
# 22335                                 WeDoData
# 29648                                  Viveris
# 46598                                      LHH
# 318474                                     TUI
# 209274       Children's National Health System
#
#                                                job_skills  \
# 309395                         ['sql', 'python', 'azure']
# 418639       ['sql', 'java', 'python', 'aws', 'redshift']
# 624247     ['python', 'sql', 'oracle', 'hadoop', 'spark']
# 425282  ['java', 'scala', 'aws', 'spark', 'kafka', 'sp...
# 701066                                      ['go', 'sql']
# 22335   ['python', 'sql', 'bash', 'pandas', 'numpy', '...
# 29648       ['sql', 'python', 'r', 'tableau', 'power bi']
# 46598                             ['excel', 'powerpoint']
# 318474                 ['tableau', 'excel', 'powerpoint']
# 209274  ['mongodb', 'mongodb', 'r', 'python', 'scala',...
#
#                                           job_type_skills
# 309395  {'cloud': ['azure'], 'programming': ['sql', 'p...
# 418639  {'cloud': ['aws', 'redshift'], 'programming': ...
# 624247  {'cloud': ['oracle'], 'libraries': ['hadoop', ...
# 425282  {'cloud': ['aws'], 'libraries': ['spark', 'kaf...
# 701066                     {'programming': ['go', 'sql']}
# 22335   {'libraries': ['pandas', 'numpy', 'scikit-lear...
# 29648   {'analyst_tools': ['tableau', 'power bi'], 'pr...
# 46598          {'analyst_tools': ['excel', 'powerpoint']}
# 318474  {'analyst_tools': ['tableau', 'excel', 'powerp...
# 209274  {'cloud': ['aws', 'azure', 'gcp', 'oracle'], '...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name = 'job_index'

# %%
df.head(10)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 7                 Data Engineer
# 8              Business Analyst
# 9                Data Scientist
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 7                                              Data Engineer
# 8                   Technology & Operations Business Analyst
# 9                                          Data Scientist II
#
#                            job_location             job_via  \
# job_index
# 0                         Watertown, CT     via Work Nearby
# 1          Guadalajara, Jalisco, Mexico    via BeBee México
# 2                       Berlin, Germany        via LinkedIn
# 3                       San Antonio, TX   via Diversity.com
# 4                        Washington, DC  via Clearance Jobs
# 5                              Anywhere    via ZipRecruiter
# 6                          Dearborn, MI        via LinkedIn
# 7                              Anywhere        via LinkedIn
# 8                   Copenhagen, Denmark     via Trabajo.org
# 9                              Anywhere    via ZipRecruiter
#
#                   job_schedule_type  job_work_from_home  \
# job_index
# 0                         Full-time               False
# 1                         Full-time               False
# 2                         Full-time               False
# 3                         Full-time               False
# 4                         Full-time               False
# 5          Contractor and Temp work                True
# 6                         Full-time               False
# 7                         Full-time                True
# 8                         Full-time               False
# 9                         Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 1                           Mexico 2023-01-14 13:18:07                  False
# 2                          Germany 2023-10-10 13:14:55                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 4                            Sudan 2023-08-07 14:29:36                  False
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 7                          Romania 2023-12-07 13:40:49                  False
# 8                          Denmark 2023-06-05 13:44:34                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States         NaN              NaN
# 1                         False         Mexico         NaN              NaN
# 2                         False        Germany         NaN              NaN
# 3                         False  United States         NaN              NaN
# 4                         False          Sudan         NaN              NaN
# 5                         False  United States         NaN              NaN
# 6                         False  United States         NaN              NaN
# 7                         False        Romania         NaN              NaN
# 8                         False        Denmark         NaN              NaN
# 9                         False  United States         NaN              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 1                      NaN     Hewlett Packard Enterprise
# 2                      NaN       ALPHA Augmented Services
# 3                      NaN   Southwest Research Institute
# 4                      NaN                Kristina Daniel
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 7                      NaN                          Zitec
# 8                      NaN                         Hempel
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                        NaN
# 1          ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2          ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4          ['bash', 'python', 'oracle', 'aws', 'ansible',...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 7          ['sql', 'nosql', 'gcp', 'azure', 'aws', 'bigqu...
# 8                        ['excel', 'powerpoint', 'power bi']
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                        NaN
# 1          {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4          {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 7          {'cloud': ['gcp', 'azure', 'aws', 'bigquery', ...
# 8          {'analyst_tools': ['excel', 'powerpoint', 'pow...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Reset_index()

# %%
df_usa = df[df['job_country']== 'United States']

# %%
df_usa.reset_index(inplace=True)
df_usa
# Out:
#         job_index       job_title_short  \
# 0               0  Senior Data Engineer
# 1               3         Data Engineer
# 2               5         Data Engineer
# 3               6  Senior Data Engineer
# 4               9        Data Scientist
# ...           ...                   ...
# 206287     785673        Data Scientist
# 206288     785685          Data Analyst
# 206289     785692        Data Scientist
# 206290     785703          Data Analyst
# 206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# 206287                    Asset Management Data Scientist      New York, NY
# 206288                                       Data Analyst  Indianapolis, IN
# 206289               Data Scientist- Hybrid Work Location        Dayton, OH
# 206290            Data Analyst - CRYPTOGRAPHY - Full-time          Anywhere
# 206291          Expert Business Data Analyst - Now Hiring       Oakland, CA
#
#                   job_via         job_schedule_type  job_work_from_home  \
# 0         via Work Nearby                 Full-time               False
# 1       via Diversity.com                 Full-time               False
# 2        via ZipRecruiter  Contractor and Temp work                True
# 3            via LinkedIn                 Full-time               False
# 4        via ZipRecruiter                 Full-time                True
# ...                   ...                       ...                 ...
# 206287    via Trabajo.org                 Full-time               False
# 206288    via Trabajo.org                 Full-time               False
# 206289    via Ai-Jobs.net                 Full-time               False
# 206290       via Snagajob                 Full-time                True
# 206291       via Snagajob                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 0            Texas, United States 2023-06-16 13:44:15                  False
# 1            Texas, United States 2023-07-04 13:01:41                   True
# 2                         Georgia 2023-11-07 14:01:59                  False
# 3          Florida, United States 2023-03-27 13:18:18                  False
# 4         New York, United States 2023-04-23 13:02:57                  False
# ...                           ...                 ...                    ...
# 206287    New York, United States 2023-10-16 06:01:53                   True
# 206288    Illinois, United States 2023-07-16 06:01:27                   True
# 206289    Illinois, United States 2023-04-21 06:02:31                  False
# 206290       Texas, United States 2023-01-28 06:02:55                   True
# 206291  California, United States 2023-01-09 06:00:25                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                      False  United States         NaN              NaN
# 1                      False  United States         NaN              NaN
# 2                      False  United States         NaN              NaN
# 3                      False  United States         NaN              NaN
# 4                      False  United States         NaN              NaN
# ...                      ...            ...         ...              ...
# 206287                 False  United States         NaN              NaN
# 206288                 False  United States         NaN              NaN
# 206289                  True  United States        year         157500.0
# 206290                 False  United States         NaN              NaN
# 206291                 False  United States         NaN              NaN
#
#         salary_hour_avg                   company_name  \
# 0                   NaN           Boehringer Ingelheim
# 1                   NaN   Southwest Research Institute
# 2                   NaN                smart folks inc
# 3                   NaN  Miracle Software Systems, Inc
# 4                   NaN     Radwell International, LLC
# ...                 ...                            ...
# 206287              NaN           JPMorgan Chase & Co.
# 206288              NaN         Aara Technologies, Inc
# 206289              NaN                         Tenet3
# 206290              NaN    Axelon Services Corporation
# 206291              NaN               PG&E Corporation
#
#                                                job_skills  \
# 0                                                     NaN
# 1       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2                                ['python', 'sql', 'gcp']
# 3       ['sql', 'python', 'java', 'sql server', 'gcp',...
# 4       ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                   ...
# 206287                                                NaN
# 206288                                   ['sql', 'excel']
# 206289                          ['python', 'matlab', 'r']
# 206290                                                NaN
# 206291                       ['sql', 'python', 'tableau']
#
#                                           job_type_skills
# 0                                                     NaN
# 1       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2       {'cloud': ['gcp'], 'programming': ['python', '...
# 3       {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 4       {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                                                   ...
# 206287                                                NaN
# 206288  {'analyst_tools': ['excel'], 'programming': ['...
# 206289         {'programming': ['python', 'matlab', 'r']}
# 206290                                                NaN
# 206291  {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 18 columns]

# %% [markdown]
# set_index()

# %%
df_usa.set_index('job_index', inplace = True)
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# 785685                                          Data Analyst
# 785692                  Data Scientist- Hybrid Work Location
# 785703               Data Analyst - CRYPTOGRAPHY - Full-time
# 785705             Expert Business Data Analyst - Now Hiring
#
#                job_location            job_via         job_schedule_type  \
# job_index
# 0             Watertown, CT    via Work Nearby                 Full-time
# 3           San Antonio, TX  via Diversity.com                 Full-time
# 5                  Anywhere   via ZipRecruiter  Contractor and Temp work
# 6              Dearborn, MI       via LinkedIn                 Full-time
# 9                  Anywhere   via ZipRecruiter                 Full-time
# ...                     ...                ...                       ...
# 785673         New York, NY    via Trabajo.org                 Full-time
# 785685     Indianapolis, IN    via Trabajo.org                 Full-time
# 785692           Dayton, OH    via Ai-Jobs.net                 Full-time
# 785703             Anywhere       via Snagajob                 Full-time
# 785705          Oakland, CA       via Snagajob                 Full-time
#
#            job_work_from_home            search_location     job_posted_date  \
# job_index
# 0                       False       Texas, United States 2023-06-16 13:44:15
# 3                       False       Texas, United States 2023-07-04 13:01:41
# 5                        True                    Georgia 2023-11-07 14:01:59
# 6                       False     Florida, United States 2023-03-27 13:18:18
# 9                        True    New York, United States 2023-04-23 13:02:57
# ...                       ...                        ...                 ...
# 785673                  False    New York, United States 2023-10-16 06:01:53
# 785685                  False    Illinois, United States 2023-07-16 06:01:27
# 785692                  False    Illinois, United States 2023-04-21 06:02:31
# 785703                   True       Texas, United States 2023-01-28 06:02:55
# 785705                  False  California, United States 2023-01-09 06:00:25
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 0                          False                 False  United States
# 3                           True                 False  United States
# 5                          False                 False  United States
# 6                          False                 False  United States
# 9                          False                 False  United States
# ...                          ...                   ...            ...
# 785673                      True                 False  United States
# 785685                      True                 False  United States
# 785692                     False                  True  United States
# 785703                      True                 False  United States
# 785705                     False                 False  United States
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0                 NaN              NaN              NaN
# 3                 NaN              NaN              NaN
# 5                 NaN              NaN              NaN
# 6                 NaN              NaN              NaN
# 9                 NaN              NaN              NaN
# ...               ...              ...              ...
# 785673            NaN              NaN              NaN
# 785685            NaN              NaN              NaN
# 785692           year         157500.0              NaN
# 785703            NaN              NaN              NaN
# 785705            NaN              NaN              NaN
#
#                             company_name  \
# job_index
# 0                   Boehringer Ingelheim
# 3           Southwest Research Institute
# 5                        smart folks inc
# 6          Miracle Software Systems, Inc
# 9             Radwell International, LLC
# ...                                  ...
# 785673              JPMorgan Chase & Co.
# 785685            Aara Technologies, Inc
# 785692                            Tenet3
# 785703       Axelon Services Corporation
# 785705                  PG&E Corporation
#
#                                                   job_skills  \
# job_index
# 0                                                        NaN
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                      ...
# 785673                                                   NaN
# 785685                                      ['sql', 'excel']
# 785692                             ['python', 'matlab', 'r']
# 785703                                                   NaN
# 785705                          ['sql', 'python', 'tableau']
#
#                                              job_type_skills
# job_index
# 0                                                        NaN
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                                                      ...
# 785673                                                   NaN
# 785685     {'analyst_tools': ['excel'], 'programming': ['...
# 785692            {'programming': ['python', 'matlab', 'r']}
# 785703                                                   NaN
# 785705     {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 17 columns]

# %% [markdown]
# sort_index()

# %%
median_pivot = df_usa.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc=['median', 'min', 'max'])

# %%
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0

# %%
median_pivot.sort_values(by=('median','salary_year_avg'),ascending=False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            155000.0         55000.0        475000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Software Engineer                130000.0         48982.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Business Analyst                  90000.0         35000.0        387460.0
# Data Analyst                      90000.0         25000.0        375000.0

# %%
median_pivot.sort_index()
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0
